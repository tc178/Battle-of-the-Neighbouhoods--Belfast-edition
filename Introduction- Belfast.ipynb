# %% [markdown]
# # Capstone Project - The Battle of Neighbourhoods (Week 1)

# %% [markdown]
# ## Introduction:

# %% [markdown]
# Given that Belfast is the closest city to my home address, I wanted to explore the data here. Since the release of Game of Thrones, most of which is shot in Northern Ireland, tourism to my home country has only grown over the recent years: “Figures from Tourism NI, the region's tourism development body, paint a similarly upbeat picture. They suggest that 350,000 people come to Northern Ireland every year just for Game of Thrones - that is one in six leisure visitors. It is estimated they spend £50m each year.” [1].
# This, alongside the newly developed Titanic museum in 2013 attracts a huge number of visitors every year- 837,000 in 2018 [3], which just shows how interest and popularity of Northern Ireland are only increasing every year.
# Given these, combined with Belfasts relatively low population- 630,000 [2]; this would be an excellent city to open a new hotel in.

# %% [markdown]
# ## Business Problem:

# %% [markdown]
# While this is no doubt an excellent time and opportunity to open a business to cater for the incoming tourists; the question remains, where should someone open a hotel to provide accommodation for these guests?
# The target audience for this problem, is going to be any possible hotel developer- let’s take Domus UK Ltd as an example. Now for Domus UK Ltd to make as an informed decision as possible, we have to research into the neighbourhoods of Belfast as much as possible. We will do this by looking at the locational data of the city.

# %% [markdown]
# ## The Data:

# %% [markdown]
# Now that Domus UK Ltd has the problem and the business opportunity outlined, how are they going to solve this using data? Fortunately Belfast has a wealth of business and corresponding locational data. Belfast is split up into 18 postcodes, with each district and location providing a range of restaurants/bars/entertainment.
# The main datasource we are going to use is going to be the Foursquare dataset. We will make use of, but not limited to the following examples for various neighbourhoods:
# -	Which area has the most/least hotels
# -	Which hotels have the highest ratings
# -	Price of the local hotels
# -	What each location has to offer for guests. I.e. bars/resturants/entertainment.
# Using all of this information, we will be able to make an analytical decision of where is best for Domus UK Ltd to open a new hotel.

# %% [markdown]
# ## References:

# %% [markdown]
# [1] 	https://www.bbc.co.uk/news/uk-northern-ireland-48343910
#
# [2]	https://worldpopulationreview.com/world-cities/belfast-population/
#
# [3] 	https://www.statista.com/statistics/649119/titanic-belfast-visitor-numbers-northern-ireland-uk/
